# %% [markdown]
# # Extending Standard Algorithms
#
# ## Content
# * [Extended Algorithm Example](#Extended-Algorithm-Example)
# * [Iterators](#Iterators)
# * [CUDA Fancy Iterators](#CUDA-Fancy-Iterators)
# * [Exercise: Computing Variance](01.03.02-Exercise-Computing-Variance.ipynb)
#
# ---
#
# Occasionally, you might encounter a use case that's not directly covered by standard algorithms.
# In this section, we'll explore techniques that can help you extend existing algorithms to your unique use cases.

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"): # If running in Google Colab:
  # !mkdir -p Sources
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/01.03-Extending-Algorithms/Sources/ach.h -nv -O Sources/ach.h
# Out:
# 2026-05-06 06:16:39 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/01.03-Extending-Algorithms/Sources/ach.h [2787/2787] -> "Sources/ach.h" [1]

# %% [markdown]
# ## Extended Algorithm Example
# Let's consider a scenario where such customization might be necessary.
# In our earlier example, we were computing the next temperature based on the previous one.
# Now let's say we have to find the maximum change in temperature made in the current step.
#
# ![Max Diff](Images/max-diff.svg "Max Diff")
#
# In the previous section, you learned how to port standard algorithms to GPU.
# It's sufficient to use `thrust::` namespace for containers and algorithms as follows.

# %%
# %%writefile Sources/naive-max-diff.cpp
# #include "ach.h"
#
# float naive_max_change(const thrust::universal_vector<float>& a,
#                        const thrust::universal_vector<float>& b)
# {
#     // allocate vector to store `a - b`
#     thrust::universal_vector<float> unnecessarily_materialized_diff(a.size());
#
#     // compute products
#     thrust::transform(thrust::device,
#                       a.begin(), a.end(),                       // first input sequence
#                       b.begin(),                                // second input sequence
#                       unnecessarily_materialized_diff.begin(),  // result
#                       []__host__ __device__(float x, float y) { // transformation (abs diff)
#                          return abs(x - y);
#                       });
#
#     // compute max difference
#     return thrust::reduce(thrust::device,
#                           unnecessarily_materialized_diff.begin(),
#                           unnecessarily_materialized_diff.end(),
#                           0.0f, thrust::maximum<float>{});
# }
#
# int main()
# {
#     float k = 0.5;
#     float ambient_temp = 20;
#     thrust::universal_vector<float> temp[] = {{ 42, 24, 50 }, { 0, 0, 0}};
#     auto transformation = [=] __host__ __device__ (float temp) { return temp + k * (ambient_temp - temp); };
#
#     std::printf("step  max-change\n");
#     for (int step = 0; step < 3; step++) {
#         thrust::universal_vector<float> &current = temp[step % 2];
#         thrust::universal_vector<float> &next = temp[(step + 1) % 2];
#
#         thrust::transform(thrust::device, current.begin(), current.end(), next.begin(), transformation);
#         std::printf("%d     %.2f\n", step, naive_max_change(current, next));
#     }
# }
# Out:
# Writing Sources/naive-max-diff.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/naive-max-diff.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# step  max-change
# 0     15.00
# 1     7.50
# 2     3.75

# %%
# %%writefile Sources/practice-naive-max-diff.cpp
# #include "ach.h"
#
# float naive_max_change(const thrust::universal_vector<float>& a,
#                         const thrust::universal_vector<float>& b)
# {
#     thrust::universal_vector<float> unnecessarily_materialized_diff(a.size());
#     thrust::transform(thrust::device, a.begin(), a.end(), b.begin(), unnecessarily_materialized_diff.begin(),
#     [] __host__ __device__ (float x, float y) {
#       return abs(x - y);
#     });
#
#     return thrust::reduce(thrust::device,
#       unnecessarily_materialized_diff.begin(),
#       unnecessarily_materialized_diff.end(),
#       0.0f,
#       thrust::maximum<float>{});
# }
#
# int main() {
#     float k = 0.5;
#     float ambient_temp = 20;
#     thrust::universal_vector<float> temp[] = {{42, 24, 50}, { 0, 0, 0}};
#     auto transformation = [=] __host__ __device__ (float temp) {
#         return temp + k * (ambient_temp - temp) ;
#     }
#
#     std::printf("step max-change\n");
#     for (int step = 0; step < 3; step++) {
#         thrust::universal_vector<float> &current = temp[step % 2];
#         thrust::universal_vector<float> &next = temp [(step + 1) % 2];
#
#         thrust::transform(thrust::device, current.begin(), current.end(), next.begin(), transformation);
#         std::printf("%d    %.2f\n", step, naive_max_change(current, next));
#     }
#
# }
# Out:
# Overwriting Sources/practice-naive-max-diff.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a-practice.out Sources/practice-naive-max-diff.cpp
# !/tmp/a-practice.out
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_for.cuh:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘void cub::CUB_200700_520_NS::CTA_SYNC()’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:240:3: error: ‘__syncthreads’ was not declared in this scope
#   240 |   __syncthreads();
#       |   ^~~~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘int cub::CUB_200700_520_NS::CTA_SYNC_AND(int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:248:10: error: ‘__syncthreads_and’ was not declared in this scope
#   248 |   return __syncthreads_and(p);
#       |          ^~~~~~~~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘int cub::CUB_200700_520_NS::CTA_SYNC_OR(int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:256:10: error: ‘__syncthreads_or’ was not declared in this scope
#   256 |   return __syncthreads_or(p);
#       |          ^~~~~~~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘void cub::CUB_200700_520_NS::WARP_SYNC(unsigned int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:264:3: error: ‘__syncwarp’ was not declared in this scope
#   264 |   __syncwarp(member_mask);
#       |   ^~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘int cub::CUB_200700_520_NS::WARP_ANY(int, unsigned int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:272:10: error: ‘__any_sync’ was not declared in this scope
#   272 |   return __any_sync(member_mask, predicate);
#       |          ^~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘int cub::CUB_200700_520_NS::WARP_ALL(int, unsigned int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:280:10: error: ‘__all_sync’ was not declared in this scope
#   280 |   return __all_sync(member_mask, predicate);
#       |          ^~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘int cub::CUB_200700_520_NS::WARP_BALLOT(int, unsigned int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:288:10: error: ‘__ballot_sync’ was not declared in this scope
#   288 |   return __ballot_sync(member_mask, predicate);
#       |          ^~~~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘unsigned int cub::CUB_200700_520_NS::SHFL_IDX_SYNC(unsigned int, int, unsigned int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:332:10: error: ‘__shfl_sync’ was not declared in this scope
#   332 |   return __shfl_sync(member_mask, word, src_lane);
#       |          ^~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh: In function ‘int cub::CUB_200700_520_NS::RowMajorTid(int, int, int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_ptx.cuh:378:37: error: ‘threadIdx’ was not declared in this scope
#   378 |   return ((block_dim_z == 1) ? 0 : (threadIdx.z * block_dim_x * block_dim_y))
#       |                                     ^~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_for.cuh: In member function ‘void cub::CUB_200700_520_NS::detail::for_each::agent_block_striped_t<PolicyT, OffsetT, OpT>::consume_tile(int, int)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_for.cuh:71:68: error: ‘threadIdx’ was not declared in this scope
#    71 |       const auto idx = static_cast<OffsetT>(block_threads * item + threadIdx.x);
#       |                                                                    ^~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/kernels/for_each.cuh: In function ‘void cub::CUB_200700_520_NS::detail::for_each::dynamic_kernel(OffsetT, OpT)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/kernels/for_each.cuh:109:52: error: ‘blockDim’ was not declared in this scope
#   109 |   const auto block_threads  = static_cast<OffsetT>(blockDim.x);
#       |                                                    ^~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/kernels/for_each.cuh:111:52: error: ‘blockIdx’ was not declared in this scope
#   111 |   const auto tile_base      = static_cast<OffsetT>(blockIdx.x) * items_per_tile;
#       |                                                    ^~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/kernels/for_each.cuh: At global scope:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/kernels/for_each.cuh:128:18: error: expected constructor, destructor, or type conversion before ‘(’ token
#   128 | __launch_bounds__(ChainedPolicyT::ActivePolicy::for_policy_t::block_threads) //
#       |                  ^
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:48,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/triple_chevron_launch.h: In member function ‘cudaError_t thrust::THRUST_200700_520_NS::cuda_cub::launcher::triple_chevron::doit_host(K, const Args& ...) const’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/triple_chevron_launch.h:68:8: error: expected primary-expression before ‘<’ token
#    68 |     k<<<grid, block, shared_mem, stream>>>(args...);
#       |        ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/triple_chevron_launch.h:68:42: error: expected primary-expression before ‘>’ token
#    68 |     k<<<grid, block, shared_mem, stream>>>(args...);
#       |                                          ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/triple_chevron_launch.h:68:48: error: expected ‘)’ before ‘...’ token
#    68 |     k<<<grid, block, shared_mem, stream>>>(args...);
#       |                                                ^~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/triple_chevron_launch.h:68:43: note: to match this ‘(’
#    68 |     k<<<grid, block, shared_mem, stream>>>(args...);
#       |                                           ^
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh: In member function ‘cudaError_t cub::CUB_200700_520_NS::detail::for_each::dispatch_t<OffsetT, OpT, PolicyHubT>::Invoke(cuda::std::__4::true_type)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:160:39: error: ‘static_kernel’ is not a member of ‘cub::CUB_200700_520_NS::detail::for_each’; did you mean ‘dynamic_kernel’?
#   160 |               .doit(detail::for_each::static_kernel<max_policy_t, OffsetT, OpT>, num_items, op);
#       |                                       ^~~~~~~~~~~~~
#       |                                       dynamic_kernel
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:160:65: error: expected primary-expression before ‘,’ token
#   160 |               .doit(detail::for_each::static_kernel<max_policy_t, OffsetT, OpT>, num_items, op);
#       |                                                                 ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:160:74: error: expected primary-expression before ‘,’ token
#   160 |               .doit(detail::for_each::static_kernel<max_policy_t, OffsetT, OpT>, num_items, op);
#       |                                                                          ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:160:79: error: expected primary-expression before ‘>’ token
#   160 |               .doit(detail::for_each::static_kernel<max_policy_t, OffsetT, OpT>, num_items, op);
#       |                                                                               ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_for.cuh:160:80: error: expected primary-expression before ‘,’ token
#   160 |               .doit(detail::for_each::static_kernel<max_policy_t, OffsetT, OpT>, num_items, op);
#       |                                                                                ^
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh: At global scope:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:923:11: error: declaration of ‘using BlockExchange = class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’ changes meaning of ‘BlockExchange’ [-fpermissive]
#   923 |     using BlockExchange = BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>;
#       |           ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:44,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_exchange.cuh:147:7: note: ‘BlockExchange’ declared here as ‘class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’
#   147 | class BlockExchange
#       |       ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:965:11: error: declaration of ‘using BlockExchange = class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’ changes meaning of ‘BlockExchange’ [-fpermissive]
#   965 |     using BlockExchange = BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>;
#       |           ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:44,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_exchange.cuh:147:7: note: ‘BlockExchange’ declared here as ‘class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’
#   147 | class BlockExchange
#       |       ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:1007:11: error: declaration of ‘using BlockExchange = class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, true, BLOCK_DIM_Y, BLOCK_DIM_Z>’ changes meaning of ‘BlockExchange’ [-fpermissive]
#  1007 |     using BlockExchange = BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, true, BLOCK_DIM_Y, BLOCK_DIM_Z>;
#       |           ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:44,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_exchange.cuh:147:7: note: ‘BlockExchange’ declared here as ‘class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, true, BLOCK_DIM_Y, BLOCK_DIM_Z>’
#   147 | class BlockExchange
#       |       ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_arch.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/config.cuh:46,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/util_debug.cuh:39,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/config.h:49,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/execution_policy.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/iterator/detail/device_system_tag.h:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/iterator/iterator_traits.h:74,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_scan_shfl.cuh: In member function ‘void cub::CUB_200700_520_NS::WarpScanShfl<T, LOGICAL_WARP_THREADS, LEGACY_PTX_ARCH>::InclusiveScan(cub::CUB_200700_520_NS::KeyValuePair<KeyT, ValueT>, cub::CUB_200700_520_NS::KeyValuePair<KeyT, ValueT>&, cub::CUB_200700_520_NS::ReduceByKeyOp<ReductionOpT>)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_scan_shfl.cuh:545:30: error: there are no arguments to ‘__clz’ that depend on a template parameter, so a declaration of ‘__clz’ must be available [-fpermissive]
#   545 |     int segment_first_lane = CUB_MAX(0, 31 - __clz(ballot));
#       |                              ^~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_scan_shfl.cuh:545:30: note: (if you use ‘-fpermissive’, G++ will accept your code, but allowing the use of an undeclared name is deprecated)
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_scan_shfl.cuh:545:30: error: there are no arguments to ‘__clz’ that depend on a template parameter, so a declaration of ‘__clz’ must be available [-fpermissive]
#   545 |     int segment_first_lane = CUB_MAX(0, 31 - __clz(ballot));
#       |                              ^~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_scan.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_scan_raking.cuh: At global scope:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_scan_raking.cuh:94:9: error: declaration of ‘using BlockRakingLayout = struct cub::CUB_200700_520_NS::BlockRakingLayout<T, cub::CUB_200700_520_NS::BlockScanRaking<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, MEMOIZE, LEGACY_PTX_ARCH>::BLOCK_THREADS>’ changes meaning of ‘BlockRakingLayout’ [-fpermissive]
#    94 |   using BlockRakingLayout = BlockRakingLayout<T, BLOCK_THREADS>;
#       |         ^~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_scan_raking.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_scan.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_raking_layout.cuh:74:8: note: ‘BlockRakingLayout’ declared here as ‘struct cub::CUB_200700_520_NS::BlockRakingLayout<T, cub::CUB_200700_520_NS::BlockScanRaking<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, MEMOIZE, LEGACY_PTX_ARCH>::BLOCK_THREADS>’
#    74 | struct BlockRakingLayout
#       |        ^~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_scan.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_scan_raking.cuh:110:9: error: declaration of ‘using WarpScan = class cub::CUB_200700_520_NS::WarpScan<T, cub::CUB_200700_520_NS::BlockScanRaking<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, MEMOIZE, LEGACY_PTX_ARCH>::RAKING_THREADS>’ changes meaning of ‘WarpScan’ [-fpermissive]
#   110 |   using WarpScan = WarpScan<T, RAKING_THREADS>;
#       |         ^~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_scan_raking.cuh:52,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_scan.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/warp_scan.cuh:161:7: note: ‘WarpScan’ declared here as ‘class cub::CUB_200700_520_NS::WarpScan<T, cub::CUB_200700_520_NS::BlockScanRaking<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, MEMOIZE, LEGACY_PTX_ARCH>::RAKING_THREADS>’
#   161 | class WarpScan
#       |       ^~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_store.cuh:837:11: error: declaration of ‘using BlockExchange = class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’ changes meaning of ‘BlockExchange’ [-fpermissive]
#   837 |     using BlockExchange = BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>;
#       |           ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:44,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_exchange.cuh:147:7: note: ‘BlockExchange’ declared here as ‘class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’
#   147 | class BlockExchange
#       |       ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_store.cuh:920:11: error: declaration of ‘using BlockExchange = class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’ changes meaning of ‘BlockExchange’ [-fpermissive]
#   920 |     using BlockExchange = BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>;
#       |           ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:44,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_exchange.cuh:147:7: note: ‘BlockExchange’ declared here as ‘class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, false, BLOCK_DIM_Y, BLOCK_DIM_Z>’
#   147 | class BlockExchange
#       |       ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_store.cuh:1003:11: error: declaration of ‘using BlockExchange = class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, true, BLOCK_DIM_Y, BLOCK_DIM_Z>’ changes meaning of ‘BlockExchange’ [-fpermissive]
#  1003 |     using BlockExchange = BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, true, BLOCK_DIM_Y, BLOCK_DIM_Z>;
#       |           ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_load.cuh:44,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:40,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_exchange.cuh:147:7: note: ‘BlockExchange’ declared here as ‘class cub::CUB_200700_520_NS::BlockExchange<T, BLOCK_DIM_X, ITEMS_PER_THREAD, true, BLOCK_DIM_Y, BLOCK_DIM_Z>’
#   147 | class BlockExchange
#       |       ^~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/warp_reduce.cuh:49,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_reduce_raking.cuh:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_reduce.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/reduce.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/find.h:65,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/mismatch.h:60,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/equal.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/equal.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/equal.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/equal.h:247,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.inl:36,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.h:601,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/vector.h:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/universal_vector.h:37,
#                  from Sources/ach.h:11,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_reduce_shfl.cuh: In member function ‘T cub::CUB_200700_520_NS::WarpReduceShfl<T, LOGICAL_WARP_THREADS, LEGACY_PTX_ARCH>::SegmentedReduce(T, FlagT, ReductionOp)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_reduce_shfl.cuh:715:27: error: there are no arguments to ‘__brev’ that depend on a template parameter, so a declaration of ‘__brev’ must be available [-fpermissive]
#   715 |     int last_lane = __clz(__brev(warp_flags));
#       |                           ^~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/warp_reduce.cuh:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_reduce_raking.cuh:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_reduce.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/reduce.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/find.h:65,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/mismatch.h:60,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/equal.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/equal.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/equal.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/equal.h:247,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.inl:36,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.h:601,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/vector.h:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/universal_vector.h:37,
#                  from Sources/ach.h:11,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_reduce_smem.cuh: In member function ‘T cub::CUB_200700_520_NS::WarpReduceSmem<T, LOGICAL_WARP_THREADS, LEGACY_PTX_ARCH>::SegmentedReduce(T, FlagT, ReductionOp, cub::CUB_200700_520_NS::Int2Type<1>)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/warp/specializations/warp_reduce_smem.cuh:242:27: error: there are no arguments to ‘__brev’ that depend on a template parameter, so a declaration of ‘__brev’ must be available [-fpermissive]
#   242 |     int next_flag = __clz(__brev(warp_flags));
#       |                           ^~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_reduce.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/reduce.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/find.h:65,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/mismatch.h:60,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/equal.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/equal.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/equal.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/equal.h:247,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.inl:36,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.h:601,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/vector.h:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/universal_vector.h:37,
#                  from Sources/ach.h:11,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_reduce_raking.cuh: At global scope:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_reduce_raking.cuh:94:9: error: declaration of ‘using BlockRakingLayout = struct cub::CUB_200700_520_NS::BlockRakingLayout<T, cub::CUB_200700_520_NS::BlockReduceRaking<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, LEGACY_PTX_ARCH>::BLOCK_THREADS>’ changes meaning of ‘BlockRakingLayout’ [-fpermissive]
#    94 |   using BlockRakingLayout = BlockRakingLayout<T, BLOCK_THREADS>;
#       |         ^~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_scan_raking.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_scan.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/core/util.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_for.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/parallel_for.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/fill.h:41,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/fill.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/fill.inl:31,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/fill.h:201,
#                  from Sources/ach.h:9,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_raking_layout.cuh:74:8: note: ‘BlockRakingLayout’ declared here as ‘struct cub::CUB_200700_520_NS::BlockRakingLayout<T, cub::CUB_200700_520_NS::BlockReduceRaking<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, LEGACY_PTX_ARCH>::BLOCK_THREADS>’
#    74 | struct BlockRakingLayout
#       |        ^~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_reduce.cuh:46,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/reduce.h:43,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/find.h:65,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/mismatch.h:60,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/equal.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/equal.h:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/equal.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/equal.h:247,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.inl:36,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/vector_base.h:601,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/vector.h:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/universal_vector.h:37,
#                  from Sources/ach.h:11,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_reduce_raking_commutative_only.cuh:108:9: error: declaration of ‘using WarpReduce = class cub::CUB_200700_520_NS::WarpReduce<T, cub::CUB_200700_520_NS::BlockReduceRakingCommutativeOnly<T, BLOCK_DIM_X, BLOCK_DIM_Y, BLOCK_DIM_Z, LEGACY_PTX_ARCH>::RAKING_THREADS>’ changes meaning of ‘WarpReduce’ [-fpermissive]
#   108 |   using WarpReduce = WarpReduce<T, RAKING_THREADS>;
#       |         ^~~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/specializations/block_reduce_raking.cuh:50,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/block/block_reduce.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_reduce.cuh:47,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/reduce.h:43,
# ...
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cpp/execution_policy.h:72,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/execution_policy.h:40,
#                  from Sources/ach.h:14,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh: At global scope:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:189:18: error: expected constructor, destructor, or type conversion before ‘(’ token
#   189 | __launch_bounds__(int(
#       |                  ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh: In member function ‘cudaError_t cub::CUB_200700_520_NS::DispatchSelectIf<InputIteratorT, FlagsInputIteratorT, SelectedOutputIteratorT, NumSelectedIteratorT, SelectOpT, EqualityOpT, OffsetT, KEEP_REJECTS, MayAlias, SelectedPolicy>::Invoke()’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:574:7: error: ‘DeviceSelectSweepKernel’ was not declared in this scope
#   574 |       DeviceSelectSweepKernel<
#       |       ^~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:575:19: error: expected primary-expression before ‘,’ token
#   575 |         MaxPolicyT,
#       |                   ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:576:23: error: expected primary-expression before ‘,’ token
#   576 |         InputIteratorT,
#       |                       ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:577:28: error: expected primary-expression before ‘,’ token
#   577 |         FlagsInputIteratorT,
#       |                            ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:578:32: error: expected primary-expression before ‘,’ token
#   578 |         SelectedOutputIteratorT,
#       |                                ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:579:29: error: expected primary-expression before ‘,’ token
#   579 |         NumSelectedIteratorT,
#       |                             ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:580:23: error: expected primary-expression before ‘,’ token
#   580 |         ScanTileStateT,
#       |                       ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:581:18: error: expected primary-expression before ‘,’ token
#   581 |         SelectOpT,
#       |                  ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:582:20: error: expected primary-expression before ‘,’ token
#   582 |         EqualityOpT,
#       |                    ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:583:16: error: expected primary-expression before ‘,’ token
#   583 |         OffsetT,
#       |                ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_select_if.cuh:585:18: error: expected primary-expression before ‘)’ token
#   585 |         MayAlias>);
#       |                  ^
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:45,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_select.cuh:48,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/copy_if.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/copy_if.h:51,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/copy_if.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/copy_if.h:62,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/copy.h:506,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_radix_sort.inl:29,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_radix_sort.h:54,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_primitive_sort.inl:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_primitive_sort.h:54,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/sort.inl:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/sort.h:65,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cpp/detail/sort.h:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cpp/execution_policy.h:72,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/execution_policy.h:40,
#                  from Sources/ach.h:14,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh: In member function ‘void cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::Scatter(Tag, OutputIt, T (&)[cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ITEMS_PER_THREAD], OffsetT (&)[cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ITEMS_PER_THREAD], OffsetT (&)[cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ITEMS_PER_THREAD], int, int, OffsetT, OffsetT)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:293:21: error: ‘threadIdx’ was not declared in this scope
#   293 |     for (int item = threadIdx.x; item < num_tile_selections; item += BLOCK_THREADS)
#       |                     ^~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh: In member function ‘OffsetT cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ConsumeFirstTile(int, OffsetT, cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ScanTileStateT&)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:361:38: error: ‘threadIdx’ was not declared in this scope
#   361 |       if ((IS_LAST_TILE) && (OffsetT(threadIdx.x * ITEMS_PER_THREAD) + ITEM >= num_tile_items))
#       |                                      ^~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:375:9: error: ‘threadIdx’ was not declared in this scope
#   375 |     if (threadIdx.x == 0)
#       |         ^~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh: In member function ‘OffsetT cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ConsumeSubsequentTile(int, int, OffsetT, cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ScanTileStateT&)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:481:38: error: ‘threadIdx’ was not declared in this scope
#   481 |       if ((IS_LAST_TILE) && (OffsetT(threadIdx.x * ITEMS_PER_THREAD) + ITEM >= num_tile_items))
#       |                                      ^~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh: In member function ‘void cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ConsumeRange(int, cub::CUB_200700_520_NS::AgentUniqueByKey<AgentUniqueByKeyPolicyT, KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, EqualityOpT, OffsetT>::ScanTileStateT&, NumSelectedIteratorT)’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:587:21: error: ‘blockIdx’ was not declared in this scope
#   587 |     int tile_idx = (blockIdx.x * gridDim.y) + blockIdx.y; // Current tile index
#       |                     ^~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:587:34: error: ‘gridDim’ was not declared in this scope
#   587 |     int tile_idx = (blockIdx.x * gridDim.y) + blockIdx.y; // Current tile index
#       |                                  ^~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/agent/agent_unique_by_key.cuh:600:11: error: ‘threadIdx’ was not declared in this scope
#   600 |       if (threadIdx.x == 0)
#       |           ^~~~~~~~~
# In file included from /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/device_select.cuh:48,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cuda/detail/copy_if.h:42,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/adl/copy_if.h:51,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/copy_if.inl:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/detail/copy_if.h:62,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/copy.h:506,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_radix_sort.inl:29,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_radix_sort.h:54,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_primitive_sort.inl:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/stable_primitive_sort.h:54,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/sort.inl:33,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/detail/sequential/sort.h:65,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cpp/detail/sort.h:30,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/system/cpp/execution_policy.h:72,
#                  from /usr/local/cuda/bin/../targets/x86_64-linux/include/thrust/execution_policy.h:40,
#                  from Sources/ach.h:14,
#                  from Sources/practice-naive-max-diff.cpp:1:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh: At global scope:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:129:18: error: expected constructor, destructor, or type conversion before ‘(’ token
#   129 | __launch_bounds__(int(
#       |                  ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh: In member function ‘cudaError_t cub::CUB_200700_520_NS::DispatchUniqueByKey<KeyInputIteratorT, ValueInputIteratorT, KeyOutputIteratorT, ValueOutputIteratorT, NumSelectedIteratorT, EqualityOpT, OffsetT, SelectedPolicy>::Invoke()’:
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:536:7: error: ‘DeviceUniqueByKeySweepKernel’ was not declared in this scope
#   536 |       DeviceUniqueByKeySweepKernel<
#       |       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:537:19: error: expected primary-expression before ‘,’ token
#   537 |         MaxPolicyT,
#       |                   ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:538:26: error: expected primary-expression before ‘,’ token
#   538 |         KeyInputIteratorT,
#       |                          ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:539:28: error: expected primary-expression before ‘,’ token
#   539 |         ValueInputIteratorT,
#       |                            ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:540:27: error: expected primary-expression before ‘,’ token
#   540 |         KeyOutputIteratorT,
#       |                           ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:541:29: error: expected primary-expression before ‘,’ token
#   541 |         ValueOutputIteratorT,
#       |                             ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:542:29: error: expected primary-expression before ‘,’ token
#   542 |         NumSelectedIteratorT,
#       |                             ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:543:23: error: expected primary-expression before ‘,’ token
#   543 |         ScanTileStateT,
#       |                       ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:544:20: error: expected primary-expression before ‘,’ token
#   544 |         EqualityOpT,
#       |                    ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:545:16: error: expected primary-expression before ‘>’ token
#   545 |         OffsetT>);
#       |                ^
# /usr/local/cuda/bin/../targets/x86_64-linux/include/cub/device/dispatch/dispatch_unique_by_key.cuh:545:17: error: expected primary-expression before ‘)’ token
#   545 |         OffsetT>);
#       |                 ^
# Sources/practice-naive-max-diff.cpp: In function ‘float naive_max_change(thrust::THRUST_200700_520_NS::cuda_cub::universal_vector<float>&, thrust::THRUST_200700_520_NS::cuda_cub::universal_vector<float>&)’:
# Sources/practice-naive-max-diff.cpp:6:5: error: ‘trust’ has not been declared
#     6 |     trust::universal_vector<float> unnecessarily_materialized_diff(a.size());
#       |     ^~~~~
# Sources/practice-naive-max-diff.cpp:6:29: error: expected primary-expression before ‘float’
#     6 |     trust::universal_vector<float> unnecessarily_materialized_diff(a.size());
#       |                             ^~~~~
# Sources/practice-naive-max-diff.cpp:7:70: error: ‘unnecessarily_materialized_diff’ was not declared in this scope
#     7 |     thrust::transform(thrust::device, a.begin(), a.end(), b.begin(), unnecessarily_materialized_diff.begin(),
#       |                                                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Sources/practice-naive-max-diff.cpp: In function ‘int main()’:
# Sources/practice-naive-max-diff.cpp:27:5: error: expected ‘,’ or ‘;’ before ‘std’
#    27 |     std::printf("step max-change\n");
#       |     ^~~
# /bin/bash: line 1: /tmp/a-practice.out: No such file or directory

# %% [markdown]
# In the code above, we started by allocating storage for products:
#
# ```c++
# thrust::universal_vector<float> unnecessarily_materialized_diff(a.size());
# ```
#
# Then, we used a version of `thrust::transform` algorithm that accepts two sequences.
# It then applies transformation to each pair of elements in these sequences.
# In our case, the transformation is computing absolute difference:
#
# ```c++
# thrust::transform(thrust::device,
#                   a.begin(), a.end(),                       // first input sequence
#                   b.begin(),                                // second input sequence
#                   diff.begin(),                             // result
#                   []__host__ __device__(float x, float y) { // transformation (abs diff)
#                       return abs(x - y);
#                   });
# ```
#
# And finally, we use `thrust::reduce` with the `thrust::maximum` operator to find the maximum absolute difference:
#
# ```c++
#     return thrust::reduce(thrust::device,
#                           unnecessarily_materialized_diff.begin(),
#                           unnecessarily_materialized_diff.end(),
#                           0.0f, thrust::maximum<float>{});
# ```
#
# Although this implementation is functionally correct, it's far from being performant.
# To discover this inefficiency, let's consider our algorithm from the memory point of view.
# Let's count all memory accesses in our naive implementation.
# As part of the transformation step,
# we read `2 * n` floats total from `a` and `b` and store `n` elements back to memory.
# As part of the reduction step, we load `n` integers.
# In total, our version performs `4 * n` memory accesses.
# However, if we were to implement this algorithm as a for loop, we'd likely write something along the lines of:
#
# ```c++
# float max_diff = 0;
# for (int i = 0; i < a.size(); i++) {
#   max_diff = std::max(max_diff, std::abs(a[i] - b[i]));
# }
# ```
#
# This raw loop only performs `2 * n` memory accesses.
# This means that materialization of products in memory leads to 2x overhead in terms of memory accesses.
# But how does this affect performance?
# Like the majority of algorithms, our algorithm is memory bound meaning the ratio of communication (memory accesses) to computation is so large that the overall performance of the code will be limited by the theoretical peak memory performance of the hardware.  As a programmer, this means we will focus performance optimizations on memory usage and data movement specifically.
# Since our algorithm is memory bound, a two-fold reduction in amount of memory accesses should result in about two-fold speedup.
# Besides performance implications, the absolute differences that we compute occupy space in memory.
# If our vectors were large enough, there might be no space left in GPU memory for them and the temporary space we use to compute and save the differences.

# %% [markdown]
# ## Iterators
# Fortunately, there's a way to avoid materializing these differences in memory and address these issues.
# The workaround consists of using iterators.
# Using an iterator can be thought of as a generalization of using a pointer:
# * A pointer, `int* pointer`, points to a sequence of integers in memory.
# * You can dereference a pointer to get access to the integer it currently points to.
# * You can advance pointer with `pointer++` to make it point to the next element in the sequence.
#
# The following code demonstrates using a pointer to access data in an array.

# %%
# %%writefile Sources/pointer.cpp
# #include "ach.h"
#
# int main()
# {
#     std::array<int, 3> a{ 0, 1, 2 };
#
#     int *pointer = a.data();
#
#     std::printf("pointer[0]: %d\n", pointer[0]); // prints 0
#     std::printf("pointer[1]: %d\n", pointer[1]); // prints 1
# }
# Out:
# Writing Sources/pointer.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/pointer.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# pointer[0]: 0
# pointer[1]: 1

# %% [markdown]
# ### Simple Counting Iterator

# %% [markdown]
# C++ allows operator overloading.
# This means that we can define what operators such as `*` or `++` do.
# The concept of an iterator builds on top of this idea.
# With this, we don't even need an underlying container.
# Here's an example of how we can create an infinite sequence without allocating a single byte.  Note the redefinition of the square brackets `[]` operator.

# %%
# %%writefile Sources/counting.cpp
# #include "ach.h"
#
# struct counting_iterator
# {
#   int operator[](int i)
#   {
#     return i;
#   }
# };
#
# int main()
# {
#   counting_iterator it;
#
#   std::printf("it[0]: %d\n", it[0]); // prints 0
#   std::printf("it[1]: %d\n", it[1]); // prints 1
# }
# Out:
# Writing Sources/counting.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/counting.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# it[0]: 0
# it[1]: 1

# %% [markdown]
# ### Simple Transform Iterator

# %% [markdown]
# Below we again redefine the square brackets `[]` operator, but this time instead of simple counting, we multiple each input value times 2.  This is an example of applying a simple function to the input before returning a value.

# %%
# %%writefile Sources/transform.cpp
# #include "ach.h"
#
# struct transform_iterator
# {
#   int *a;
#
#   int operator[](int i)
#   {
#     return a[i] * 2;
#   }
# };
#
# int main()
# {
#   std::array<int, 3> a{ 0, 1, 2 };
#
#   transform_iterator it{a.data()};
#
#   std::printf("it[0]: %d\n", it[0]); // prints 0 (0 * 2)
#   std::printf("it[1]: %d\n", it[1]); // prints 2 (1 * 2)
# }
# Out:
# Writing Sources/transform.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/transform.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# it[0]: 0
# it[1]: 2

# %% [markdown]
# ### Simple Zip Iterator

# %% [markdown]
# We can continue to redefine the square brackets `[]` operator, to combine multiple sequences.  The zip iterator below takes two arrays and combines them into a sequence of tuples.

# %%
# %%writefile Sources/zip.cpp
# #include "ach.h"
#
# struct zip_iterator
# {
#   int *a;
#   int *b;
#
#   std::tuple<int, int> operator[](int i)
#   {
#     return {a[i], b[i]};
#   }
# };
#
# int main()
# {
#   std::array<int, 3> a{ 0, 1, 2 };
#   std::array<int, 3> b{ 5, 4, 2 };
#
#   zip_iterator it{a.data(), b.data()};
#
#   std::printf("it[0]: (%d, %d)\n", std::get<0>(it[0]), std::get<1>(it[0])); // prints (0, 5)
#   std::printf("it[1]: (%d, %d)\n", std::get<0>(it[1]), std::get<1>(it[1])); // prints (1, 4)
# }
# Out:
# Writing Sources/zip.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/zip.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# it[0]: (0, 5)
# it[1]: (1, 4)

# %% [markdown]
# ### Combining Input Iterators

# %% [markdown]
# One very powerful feature of iterators is that you can combine them with each other.  If we think about our original code above where we computed the absolute value of the difference between each element in two arrays, you can see below that we can combine, or nest, the zip_iterator with the transform_iterator to first combine the two arrays `a` and `b` with zip, and then transform them via the transform iterator with our custom operation to compute the absolute value of the differences of each successive element in the original arrays `a` and `b`.

# %%
# %%writefile Sources/transform-zip.cpp
# #include "ach.h"
#
# struct zip_iterator
# {
#   int *a;
#   int *b;
#
#   std::tuple<int, int> operator[](int i)
#   {
#     return {a[i], b[i]};
#   }
# };
#
# struct transform_iterator
# {
#   zip_iterator zip;
#
#   int operator[](int i)
#   {
#     auto [a, b] = zip[i];
#     return abs(a - b);
#   }
# };
#
# int main()
# {
#   std::array<int, 3> a{ 0, 1, 2 };
#   std::array<int, 3> b{ 5, 4, 2 };
#
#   zip_iterator zip{a.data(), b.data()};
#   transform_iterator it{zip};
#
#   std::printf("it[0]: %d\n", it[0]); // prints 5
#   std::printf("it[1]: %d\n", it[1]); // prints 3
# }
# Out:
# Writing Sources/transform-zip.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/transform-zip.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# it[0]: 5
# it[1]: 3

# %% [markdown]
# ### Transform Output Iterator

# %% [markdown]
# The concept of iterators is not limited to inputs alone.  With another level of indirection one can transform values that are written into a transform output iterator.  Note in the code below, both `=` and `[]` operators are being redefined.

# %%
# %%writefile Sources/transform-output.cpp
# #include "ach.h"
#
# struct wrapper
# {
#    int *ptr;
#
#    void operator=(int value) {
#       *ptr = value / 2;
#    }
# };
#
# struct transform_output_iterator
# {
#   int *a;
#
#   wrapper operator[](int i)
#   {
#     return {a + i};
#   }
# };
#
# int main()
# {
#   std::array<int, 3> a{ 0, 1, 2 };
#   transform_output_iterator it{a.data()};
#
#   it[0] = 10;
#   it[1] = 20;
#
#   std::printf("a[0]: %d\n", a[0]); // prints 5
#   std::printf("a[1]: %d\n", a[1]); // prints 10
# }
# Out:
# Writing Sources/transform-output.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/transform-output.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# a[0]: 5
# a[1]: 10

# %% [markdown]
# ### Discard Iterator

# %%
# %%writefile Sources/discard.cpp
# #include "ach.h"
#
# struct wrapper
# {
#    void operator=(int value) {
#       // discard value
#    }
# };
#
# struct discard_iterator
# {
#   wrapper operator[](int i)
#   {
#     return {};
#   }
# };
#
# int main()
# {
#   discard_iterator it{};
#
#   it[0] = 10;
#   it[1] = 20;
# }
# Out:
# Writing Sources/discard.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/discard.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable

# %% [markdown]
# ## CUDA Fancy Iterators
#
# CUDA Core Libraries provide a variety of iterators.
# Let's take a look at some of them as we try to improve the performance of our inner product implementation.
# The first step is computing the absolute differences of corresponding vector components.
# To do that, we have to somehow make operator `*` return a pair of values, one taken from `a` and another taken from `b`.
# This functionality is covered by `thrust::zip_iterator`.

# %%
# %%writefile Sources/zip.cpp
# #include "ach.h"
#
# int main()
# {
#     // allocate and initialize input vectors
#     thrust::universal_vector<float> a{ 31, 22, 35 };
#     thrust::universal_vector<float> b{ 25, 21, 27 };
#
#     // zip two vectors into a single iterator
#     auto zip = thrust::make_zip_iterator(a.begin(), b.begin());
#
#     thrust::tuple<float, float> first = *zip;
#     std::printf("first: (%g, %g)\n", thrust::get<0>(first), thrust::get<1>(first));
#
#     zip++;
#
#     thrust::tuple<float, float> second = *zip;
#     std::printf("second: (%g, %g)\n", thrust::get<0>(second), thrust::get<1>(second));
# }
# Out:
# Overwriting Sources/zip.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/zip.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# first: (31, 25)
# second: (22, 21)

# %% [markdown]
# However, we don't need just pairs of vector components.
# We need their absolute differences.
# A `thrust::transform_iterator` allows us to attach a function to the dereferencing of an iterator.
# When combined with the zip iterator, it allows us to compute absolute differences without materializing them in memory.

# %%
# %%writefile Sources/transform.cpp
# #include "ach.h"
#
# int main()
# {
#     thrust::universal_vector<float> a{ 31, 22, 35 };
#     thrust::universal_vector<float> b{ 25, 21, 27 };
#
#     auto zip = thrust::make_zip_iterator(a.begin(), b.begin());
#     auto transform = thrust::make_transform_iterator(zip, []__host__ __device__(thrust::tuple<float, float> t) {
#         return abs(thrust::get<0>(t) - thrust::get<1>(t));
#     });
#
#     std::printf("first: %g\n", *transform); // absolute difference of `a[0] = 31` and `b[0] = 25`
#
#     transform++;
#
#     std::printf("second: %g\n", *transform); // absolute difference of `a[1] = 22` and `b[1] = 21`
# }
# Out:
# Overwriting Sources/transform.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/transform.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# first: 6
# second: 1

# %% [markdown]
# The only remaining part is computing a maximum value.
# We already know how to do that using `thrust::reduce`.
#
# Now, the code below is functionally equivalent to our starting code example at the top of this notebook.  Notice we have eliminated the need for the temporary array to store the differences.

# %%
# %%writefile Sources/optimized-max-diff.cpp
# #include "ach.h"
#
# float max_change(const thrust::universal_vector<float>& a,
#                  const thrust::universal_vector<float>& b)
# {
#     auto zip = thrust::make_zip_iterator(a.begin(), b.begin());
#     auto transform = thrust::make_transform_iterator(zip, []__host__ __device__(thrust::tuple<float, float> t) {
#         return abs(thrust::get<0>(t) - thrust::get<1>(t));
#     });
#
#     // compute max difference
#     return thrust::reduce(thrust::device, transform, transform + a.size(), 0.0f, thrust::maximum<float>{});
# }
#
# int main()
# {
#     float k = 0.5;
#     float ambient_temp = 20;
#     thrust::universal_vector<float> temp[] = {{ 42, 24, 50 }, { 0, 0, 0}};
#     auto transformation = [=] __host__ __device__ (float temp) { return temp + k * (ambient_temp - temp); };
#
#     std::printf("step  max-change\n");
#     for (int step = 0; step < 3; step++) {
#         thrust::universal_vector<float> &current = temp[step % 2];
#         thrust::universal_vector<float> &next = temp[(step + 1) % 2];
#
#         thrust::transform(thrust::device, current.begin(), current.end(), next.begin(), transformation);
#         std::printf("%d     %.2f\n", step, max_change(current, next));
#     }
# }
# Out:
# Writing Sources/optimized-max-diff.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/optimized-max-diff.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# step  max-change
# 0     15.00
# 1     7.50
# 2     3.75

# %% [markdown]
# Recall that this code is memory bound, so we'd expect that the elimination of unnecessary memory usage (in this case, temporary storage to hold the differences) should improve our performance. Let's evaluate performance of this implementation to see if it matches our intuition.
# To do that, we'll allocate much larger vectors.

# %%
# %%writefile Sources/naive-vs-iterators.cpp
# #include "ach.h"
#
# float naive_max_change(const thrust::universal_vector<float>& a,
#                        const thrust::universal_vector<float>& b)
# {
#     thrust::universal_vector<float> diff(a.size());
#     thrust::transform(thrust::device, a.begin(), a.end(), b.begin(), diff.begin(),
#                       []__host__ __device__(float x, float y) {
#                          return abs(x - y);
#                       });
#     return thrust::reduce(thrust::device, diff.begin(), diff.end(), 0.0f, thrust::maximum<float>{});
# }
#
# float max_change(const thrust::universal_vector<float>& a,
#                  const thrust::universal_vector<float>& b)
# {
#     auto zip = thrust::make_zip_iterator(a.begin(), b.begin());
#     auto transform = thrust::make_transform_iterator(zip, []__host__ __device__(thrust::tuple<float, float> t) {
#         return abs(thrust::get<0>(t) - thrust::get<1>(t));
#     });
#     return thrust::reduce(thrust::device, transform, transform + a.size(), 0.0f, thrust::maximum<float>{});
# }
#
# int main()
# {
#     // allocate vectors containing 2^28 elements
#     thrust::universal_vector<float> a(1 << 28);
#     thrust::universal_vector<float> b(1 << 28);
#
#     thrust::sequence(a.begin(), a.end());
#     thrust::sequence(b.rbegin(), b.rend());
#
#     auto start_naive = std::chrono::high_resolution_clock::now();
#     naive_max_change(a, b);
#     auto end_naive = std::chrono::high_resolution_clock::now();
#     const double naive_duration = std::chrono::duration_cast<std::chrono::milliseconds>(end_naive - start_naive).count();
#
#     auto start = std::chrono::high_resolution_clock::now();
#     max_change(a, b);
#     auto end = std::chrono::high_resolution_clock::now();
#     const double duration = std::chrono::duration_cast<std::chrono::milliseconds>(end - start).count();
#
#     std::printf("iterators are %g times faster than naive approach\n", naive_duration / duration);
# }
# Out:
# Writing Sources/naive-vs-iterators.cpp

# %%
# !nvcc --extended-lambda -o /tmp/a.out Sources/naive-vs-iterators.cpp -x cu -arch=native # build executable
# !/tmp/a.out # run executable
# Out:
# iterators are 28.6667 times faster than naive approach

# %% [markdown]
# The resulting speedup exceeds our expectations because we included memory allocation in our measurements.
#
# ---
# Proceed to [the exercise](01.03.02-Exercise-Computing-Variance.ipynb).
